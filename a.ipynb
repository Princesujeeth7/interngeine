# %%
from langchain_community.document_loaders import PyPDFLoader,UnstructuredFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community import output_parsers
from langchain_community.vectorstores import Chroma 
from langchain_community.llms import Ollama
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
import streamlit as st
import glob
import os
import pandas as pd
from langchain_core.documents import Document
from langchain_unstructured import UnstructuredLoader
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores.utils import filter_complex_metadata

# %%
base_path = os.path.join(os.getcwd(), "data")  
pdf_paths = glob.glob(os.path.join(base_path, "**", "*.pdf"), recursive=True)
docx_paths = glob.glob(os.path.join(base_path, "**", "*.docx"), recursive=True)
all_documents = []

for path in pdf_paths:
        try:
            loader = PyPDFLoader(path)
            docs = loader.load()
            all_documents.extend(docs)
        except Exception as e:
            print(f"Error loading {path}: {e}")

for path in docx_paths:
        try:
            loader = UnstructuredFileLoader(path)
            docs = loader.load()
            all_documents.extend(docs)
        except Exception as e:
            print(f"❌ Error loading DOCX {path}: {e}")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21840\1300657350.py:16: LangChainDeprecationWarning: The class `UnstructuredFileLoader` was deprecated in LangChain 0.2.8 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-unstructured package and should be used instead. To use it run `pip install -U :class:`~langchain-unstructured` and import as `from :class:`~langchain_unstructured import UnstructuredLoader``.
#   loader = UnstructuredFileLoader(path)

# %%
all_documents
# Out:
# [Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 0, 'page_label': '1'}, page_content='INTERN TALK\nData Science and Artificial Intelligence Tensor'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 1, 'page_label': '2'}, page_content='•\n•\n•\n•\n•\nValuable experience, and industrial exposure.\nChance for pre-placement offers (PPOs).\nProvides edge in placement interviews.\nStipend :)\nInternship Data: 2023, 2022, \nWhy Internships?\nNishchay Nilabh, Product Engineer @ Sprinklr'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 2, 'page_label': '3'}, page_content='Slot Spot\nYou have a preference order No preference order, first offer is final offer'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 3, 'page_label': '4'}, page_content='Internship\nProcess\nCV Submission\nAround mid-July, 1 week before first coding test\nApply for Company & CV Shortlisting\nAn email will notify you when a company comes for \nhiring interns.\nScreening Tests\nAn online/offline test will conducted. Coding tests \nusually have 3-5 questions to be solved in limited time\nInterviews\nGenerally 2-3 rounds of interviews, technical ones \nfollowed by HR interview\nSlot 1 Spot 1 Slot 2 Spot 2\nInfinte Spot'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 4, 'page_label': '5'}, page_content='Resume Structure \n(LaTeX Template)'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 5, 'page_label': '6'}, page_content='• Experiences\n• Achievements• Projects\n• Technical Skills • Key Courses\n• PORs'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 6, 'page_label': '7'}, page_content='•\n•\n•\n•\n•\n•\nSDE (Aryan Lath & vrooon, SWE Intern @ Google)\nQuant (Aditya Gupta, Quant Intern @ Quadeye)\nML/Data Science (Shantanu Chaudhari, DS Intern @ Infoedge)\nResearch [MITACS, EPFL,  …]\nDesign\nOff-campus\nRoles'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 7, 'page_label': '8'}, page_content='•\n•\n•\n•\n•\n•\n•\n•\nSirf YouTube tutorials dekhne se coding nahi hota\nDSA & CP : most important for SDE role \nPractice DSA from leetcode.com / interviewbit.com\nCP helps cracking coding interviews (so try giving contests regularly) \nInterviews consist of problem solving(DSA), project & resume discussion.\nSometimes interviewer can go in depth of your project/code so better to get thorough with your \nproject.\nPrepare a brief summary of all your projects beforehand if the interviewer asks you to explain one. \nExpect questions like "Why did you use this techstack and not something else" etc.\nAlso mention only those things/features in your project that you are confident about and can answer \ncounter questions. \nIn specific profiles (like Systems), interviewers can also grill you on CS fundamentals (like COA, DBMS \nor any other course specified by you in your resume), OOPS…\nSDE'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 8, 'page_label': '9'}, page_content='•\n•\nWhat do these companies (HFTs) do?\nHigh-frequency trading, also known as HFT, is a method of trading that uses powerful computer programs and \nhighly complex algorithms to transact a large number of orders in fractions of a second. \nAlthough these companies are financial firms, they do not expect financial knowledge from students during \ninterviews/shortlisting.\nOncampus - Quadeye/Alphagrep/Ebullient/JaneStreet* \nRoles - Quant/Systems\nQuant & Systems'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 9, 'page_label': '10'}, page_content='•\n•\nWhat are they looking for?\nHigh CPI : You must have a 9+ CPI and the better department rank the better it is.\nMostly CS/MnC/DSAI* : Although they are open for circuital branches, but mostly hire from CS/ MnC/DSAI. \nThese companies seem to give a lot of weightage to JEE Advance ranks in their selection process\nQuant & Systems\nOff campus hiring\nRelatively few quant companies visit our campus. There are many more companies out there that also have off \ncampus hirings. Try to apply for the ones which don’t visit our campus for now. Example: NK Securitites, Tower \nResearch, Quantbox, Graviton, Optiver.\nGS/JP: Quant Role is also offered by investment banking companies, but they do not have strict \ncriteria like HFTs, but the prep material for interviews is the same.'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 10, 'page_label': '11'}, page_content="•\n•\n•\n•\n•\n•\n•\n•\n•\n•\n•\nResources\nCourses\nProbability Theory and Random Processes\nStatistics 110 : Youtube playlist by harvard university.\nBooks\n50 Challenging Problems in Probability \nHeard on the Street: Quantitative Questions from Wall Street Job Interviews \nXinfeng Zhou \nPeter Winkler   \nPuzzles from https://brainstellar.com/\nMuch more - https://github.com/tejas01101001/Quant\nDon't forget DSA!!\nQuant"),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 11, 'page_label': '12'}, page_content='•\n•\n•\n•\n•\nResources\nCourses: The Cherno C++ Playlist\nOther Materials\nC++ Object Model Internals: https://www.avabodh.com/cxxin/cxx.html\nSpecific topics from GeeksForGeeks like virtual functions, smart pointers.\nDSA Required! Similar questions from InterviewBit, Leetcode.\nSystems'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 12, 'page_label': '13'}, page_content="ML/DS\n•\n•\n•\n•\n•\n•\n•\n•\n•\nSome OA's are purely ML/DL based, whilst some may also ask DSA, so prep both\nThe role is mostly related to NLP tasks (Microsoft, Adobe) and CV (KLA) in a very few places.\nSome companies offer Industrial role whilst some offer research, choose based on your preference\nMost companies expect a very good grasp of vanilla ML concepts and the mathematics behind it (A good \nresource is StatQuest YouTube channel), DL is added cherry on top, though not necessary (unless you did a \nproject in it)\nProjects show your understanding of the thingy, so its crutial to make and deploy projects, some ideas are:\nKaggle competitions, Course projects, Hackathon, Club projects, Own ideas, etc…\nMake sure you understand every aspect of your project, it may put a bad mark against you\nYou might also be asked to perform EDA/ make models in your interviews (without using documentation), so do \nhands on practice as well.\nML companies are scarse and Luck is a thing so keep SDE role as a backup and prepare DSA/CP as well."),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 13, 'page_label': '14'}, page_content='Resources\na.\nb.\nc.\nd.\ne.\n1.\na.\nb.\n2.\n3.\nInterview Experience \n2018-2020 (CSEA)\n2021 (CSEA)\n2022 (CSEA)\n2023 (Tensor)\nCepstrum Inplex\nInternship Data\n2023\n2022\nCSEA Internship Prep Resources'),
#  Document(metadata={'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creator': 'Chromium', 'creationdate': '2024-01-25T18:39:31+00:00', 'moddate': '2024-01-25T18:39:32+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf', 'total_pages': 15, 'page': 14, 'page_label': '15'}, page_content='THANKYOU'),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 0, 'page_label': '1'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 1, 'page_label': '2'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 2, 'page_label': '3'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 3, 'page_label': '4'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 4, 'page_label': '5'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 5, 'page_label': '6'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 6, 'page_label': '7'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 7, 'page_label': '8'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 8, 'page_label': '9'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 9, 'page_label': '10'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 10, 'page_label': '11'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 11, 'page_label': '12'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 12, 'page_label': '13'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 13, 'page_label': '14'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 14, 'page_label': '15'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 15, 'page_label': '16'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 16, 'page_label': '17'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 17, 'page_label': '18'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 18, 'page_label': '19'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 19, 'page_label': '20'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 20, 'page_label': '21'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 21, 'page_label': '22'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 22, 'page_label': '23'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 23, 'page_label': '24'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 24, 'page_label': '25'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 25, 'page_label': '26'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 26, 'page_label': '27'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 27, 'page_label': '28'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 28, 'page_label': '29'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 29, 'page_label': '30'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 30, 'page_label': '31'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 31, 'page_label': '32'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 32, 'page_label': '33'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 33, 'page_label': '34'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 34, 'page_label': '35'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 35, 'page_label': '36'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 36, 'page_label': '37'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 37, 'page_label': '38'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 38, 'page_label': '39'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 39, 'page_label': '40'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 40, 'page_label': '41'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 41, 'page_label': '42'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 42, 'page_label': '43'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 43, 'page_label': '44'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 44, 'page_label': '45'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 45, 'page_label': '46'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 46, 'page_label': '47'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 47, 'page_label': '48'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 48, 'page_label': '49'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 49, 'page_label': '50'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 50, 'page_label': '51'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 51, 'page_label': '52'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 52, 'page_label': '53'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 53, 'page_label': '54'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 54, 'page_label': '55'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 55, 'page_label': '56'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 56, 'page_label': '57'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 57, 'page_label': '58'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 58, 'page_label': '59'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 59, 'page_label': '60'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 60, 'page_label': '61'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 61, 'page_label': '62'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 62, 'page_label': '63'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 63, 'page_label': '64'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 64, 'page_label': '65'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 65, 'page_label': '66'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 66, 'page_label': '67'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 67, 'page_label': '68'}, page_content=''),
#  Document(metadata={'producer': 'iLovePDF', 'creator': 'Canva', 'creationdate': '2025-01-13T08:18:16+00:00', 'keywords': 'DAGbxsAStjY,BAFWJgqrQQI', 'author': 'Rajeshwari', 'title': 'Add a short description', 'moddate': '2025-01-14T06:29:22+00:00', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\Intern_Talk_2025.pdf', 'total_pages': 69, 'page': 68, 'page_label': '69'}, page_content=''),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 0, 'page_label': '1'}, page_content='B y  C S E A\nI N T E R N  T A L K  &\nS E M E S T E R - 4\nA C A D E M I C  T A L K'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 1, 'page_label': '2'}, page_content='Academic Talk\nA G E N D A \nWe have received multiple\nquestions on how to prepare\nfor intern season and we\nthought we would address all\nthe queries in this talk. \nWe will also give you a brief\noverview of the courses you\nhave this semester.\nIntern Talk\nOthers\nQ&A'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 2, 'page_label': '3'}, page_content="C O U R S E S \nCS205 Formal Languages, Automata Theory and\nComputation - 6 credits\nCS207 Design and Analysis of Algorithms - 6 credits\nCS223 Computer Architecture and Organization - 6 credits\nCS224 Hardware Lab - 6 credits\nCS245 Database Management Systems - 6 credits\nCS246 Database Management Systems Lab - 4 credits\nHS1xx HSS Elective -I Level-I - 6 credits\nSA3xx Students' Activity Course-III"),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 3, 'page_label': '4'}, page_content='CS205:  Formal Languages, Automata \nTheory and Computation - 6 credits\nFSMs, DFAs, Non-DFAs, Turing Machines, Grammars are the main\nfocus of this course.\nYou will also learn how all these are implemented in a Computer.\nThis course has lots of proof. You will enjoy the initial part but it\nbecomes a bit confusing in the later part.\nThis is not a very important course unless you are interested in\ncompilers or want to pursue higher studies.\nHaving a clarity of things helps in scoring well in this course.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 4, 'page_label': '5'}, page_content='CS207: Design and Analysis of \nAlgorithms - 6 credits\nYou will be introduced to some new and some familiar techniques such as\ngreedy, DP, Network flows etc.\nImportant Algorithms will be taught in this course. Eg: Kruskal, Prims,\nDijkstra etc. \nYou will be taught how to analyse different types of algorithms. Like how to\nprove the time complexity, the correctness, the termination of the\nalgorithm etc. \nThe above points also help in interviews during algorithm’s analysis in\nvarious aspects.\nCP really helps in this course.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 5, 'page_label': '6'}, page_content='CS223: Computer Architecture and Organization \n- 6 credits\nThe second half of the course is of more importance and is also\nsometimes asked during interviews - IF you mention it and the\ninterviewer is experienced. \nIn the next semester you will be studying Operating Systems(important\ncourse) and COA acts as a prerequisite for that course. \nHelps in understanding how modern CPU and memory/cache works. \nThe structure of the course is well balanced and the provided materials\nwould be sufficient.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 6, 'page_label': '7'}, page_content='CS224: Hardware Lab - 6 credits\nThis is a lab course based on what you have learned in Digital Design\nand what you learn in Computer Architecture and Organization.\nThe assignments and their difficulty depends on the course structure\nand the professor. As you have Karfa Sir, expect very hard assignments\nthat might (will) eat up your entire weekend.\nLearn Verilog as this is going to be a hands-on lab.\nYour implementation can be correct but you won’t be able to score\nunless the TA understands it as well. So make sure that the TA\nunderstands your implementation. \nHe takes 2 quizzes which usually determine a major percentage of\nyour grade.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 7, 'page_label': '8'}, page_content='CS245 Database Management Systems\n - 6 credits\n Very straightforward theory.\nSQL part is basic and becomes little complex towards the end, so\nbetter to pay attention throughout. \nNon SQL part is very theoretical in nature and is of high\nimportance at the industry level and interviewers expect that you\nunderstand that part clearly.\nThings like ACID properties, Indexing, Normalization,\nTransactions, B+ trees etc are frequently asked in interviews.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'author': 'Sanjana Kolisetty', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'total_pages': 28, 'page': 8, 'page_label': '9'}, page_content='CS246 Database Management Systems\nLab - 4 credits\nIt’s a weekly lab with a set of questions assigned which are to be\nsolved and submitted by the end of the lab session.\nQuestions are usually medium level. \nHaving a good knowledge of SQL will make this lab a cakewalk.\nYou can take help from this GitHub Repo. It has all the\nassignments and their solution codes as well, of Jan-May 2023\n(Vijaya Saradhi & Purandar Bhaduri)\nThe endsem taken (quiz-format) usually determines a major part\nof your grade.'),
# ...
#  Document(metadata={'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Internship Interview Experiences\\Trilogy.docx'}, page_content="TRIOLOGY interveiw questions and experiences\n\nAnindya Vijayvargeeya (not selected)\n\nBefore interviews, we had a coding round with 4 qs (I solved 2 of them, 2nd and 3rd, people who solved only 1st and 2nd weren’t selected), and then we had CCAT, which had mental ability, English and Arithmetic qs. 15mins for 50 qs and a 40/50 score was required for eligibility for further rounds.\n\nRound 0 \n\n(Project discussion round, about 30 mins) :\n\nAfter a quick hi-hello, the interviewer told me to pick a project to talk about. I had built a note-taking app (similar to Google Docs or Notion) and was most confident in that. He probably didn’t look at the projects before the interview. He went on to ask about every single detail of this project. Some specific qs he asked that I remember-\n\nWalk me through all the features of your app, starting from login.\n\nWhat difficulties did you face working on this project?\n\nTold him that this was a learning project and I had to learn so many different things, that was a big challenge. Then moved to describe the specific problem of implementing WYSIWYG editors. He then asked me how did I solve that, and that was basically\n\nWhich databases did you use? Why was this the best way to store data for this app?\n\nTold me to write down the entire schema\n\nTo justify the use of SQL I had to write some sample queries in SQL and MongoDB\n\nIf let's say you have to add a new feature and add permission for users like in Google Docs, how will you modify your schema for that?\n\nHow did you manage concurrency with multiple users working on your app simultaneously?\n\nTold him about the libraries I used to support this, slate.js and socket.io\n\nI described their inner working to explain how concurrency is handled in my app, then had to write some React code to explain what I had to do.\n\nHow scalable is your app?\n\nTold him that I need to implement a Redis cache and improve the way I save documents to make it more scalable\n\nWhat are your future plans with this project? What features would you like to add?\n\nWere you able to achieve what you intended with this project?\n\nMy aim was just to learn, so told him about all the various cool stuff I learned. And one thing I learned was GraphQL, then he asked me the final q-\n\nWhy did you use GraphQL? What are its benefits over REST and what are its limitations?\n\n\n\nFor the limitations, I mentioned that GraphQL had to implement its own caching mechanism, but forgot to mention the n+1 problem. If you used GraphQL in your project do look up this.\n\nRound 1\n\n( Coding Round, about 1 hr):\n\nFirst, the interviewer asked me about my projects. We had a short project discussion, involving typical questions like what was your idea for the project and so on. \n\nHe then asked, “which one did you like more, cp or projects?”\n\nI answered they both are related and required to get better at coding. Cp is solving problems short term while developing problem-solving abilities, which working projects would be long term, taking weeks or months, where we’re trying to apply would problem-solving abilities to solve real-world problems in a meaningful way.\n\nThen he moved on to asking DSA. He started with “how good are you in DSA?” then he gave me this q- Given an n-ary rooted tree, a signal is given to the root at time t=0. Every second, all nodes having the signal pass it on to one of their children (while also retaining it themselves). How much time will it take for all nodes of the tree to get the signal?\n\nIt took a lot of time to arrive at the answer, although it is actually simple. One thing I learned from this is that it's better to try out a few test cases to get a better feel of the question and it will also clarify the question. The solution involves running a dfs over the tree and for each node we calculate time  ...
#  Document(metadata={'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Internship Interview Experiences\\Uber.docx'}, page_content="Uber company interveiw questions and experiences 2021\n\nCoding Round (1 hour)\n\nConvert a number from Base 2 to Base 6. The number was given as a vector containing 100 binary digits, and we had to return an output vector. (Since the number is too large to fit in long long in c++, the question is simple if you use python). Most people could only solve this partially.\n\nYou have n positions and you can fill each position with a number from l to r. How many arrangements can you have such that the sum of numbers is a multiple of 3? (n was 10^5 and l, r were between 1 and 10^9)\n\nFind the number of ways to construct a building with n floors of three types, Official, residential and cafeteria. Subject to conditions:\n\nThere can be at most one cafeteria.\n\nThere cannot be three or more consecutive official floors.\n\nPeople who solved Q2&Q3 completely + Q1 at least partially, were shortlisted for the interviews.\n\nStats:\n\nRound 1: 16 shortlisted\n\nRound 2: 8 shortlisted\n\nHR Round: 6 shortlisted\n\nFinal Selection List: 2 people (does not include people who got companies higher on their preference list)\n\nPranav Vinchurkar\n\n1st round (45 mins)\n\nI have N machines which have to function in a particular order. I also have M conditions, each of form (A, B): Machine A will have to function before Machine B. \n\nQuestion: How will you check if there is a possible ordering of machines, such that all of them function. (Solution: Consider each machine as a node of a graph. If A has to function before B, make a directed edge from node A to node B. There is a valid ordering, if the graph has no directed cycles. Do that by running a simple DFS (Each node has 3 states: Unprocessed, \n\n\n\nprocessing, processed. When you enter a node, mark it as processing, and when you exit it, mark it as processed. If you try to enter a node which is already under processing, you have found a directed cycle)\n\nThen she asked me to code it (Print yes/no), and run my code on a few test cases.\n\nThen I was asked to print any valid ordering (topological sort)\n\nThen I was asked about the time complexity of my code, and justify it.\n\nSince time was left, the interviewer started speaking about life at Uber and told me that she trains/mentors interns as well.\n\n2nd round (45 mins)\n\nMy interviewer was a IITM CSE graduate\n\nThis round was simple, it was about being able to implement classes.\n\nI have a restaurant menu. The menu can contain several dishes and each dish has several ingredients. Dishes have properties like price, name, etc.\n\nI want to be able to support the following operations: (initially just a few basic operations)\n\n1 ) Insert a dish in the menu\n\n2 ) Display all dishes of the menu\n\n3 ) Count the number of dishes in the manu with a particular ingredient.\n\nI created a class called Dish. It stored a vector of ingredients.\n\nAnd I also created a class Menu, which has a vector containing objects of class Dish. \n\nAdded supporting functions in classes as needed. Simple brute force.\n\nThen he asked me to modify the classes to I can support more operations:\n\n1 ) Return all pairs of dishes with total price <=X. (just did quadratic brute force)\n\n2 ) Return Dishes which have a particular ingredient and don’t have a particular ingredient.\n\n3 ) Combination of 1) and 2), did not have to code this one, just was asked how would I make sure the code for this doesn’t get messy.\n\n3rd round (HR round) (30 mins)\n\nThen I was asked to choose any project I had done and explain every single detail/technologies used. The interviewer enthusiastically listened to whatever I described, and asked a lot of follow up questions. \n\nHe then asked me what challenges I faced while making it, why I decided to make the project, what improvements can be made, etc. \n\nThen I was asked how I would design  ...
#  Document(metadata={'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Internship Interview Experiences\\UIPath.docx'}, page_content="UIPath interveiw questions and experiencs 2021\n\nKunal Maan:\n\nIn each of the first two interviews, only 2 coding questions were asked (easy compared to the online test). We had to write the code and also run the test cases. I’d suggest going through this link and standard questions on Interviewbit before the interview. The interviewers were very friendly. \n\nOnly two students gave the third round (HR round) in which the interviewer asked about all the projects on my resume and the motive behind them. He also asked why I chose those specific technologies over others for doing the project. Apart from this it was just a discussion on my hobbies and things I like to do in my free time.\n\nRound 1: \n\nQ1. Given nested lists in the input, we had to find the sum of the depth of the list multiplied by the elements in the list. \n\nThe question was a little vague as it was not clear as to how we had to take the input. So I discussed this with the interviewer and he said it was okay to take a vector of vectors even though that method would only work for inputs where the max depth was 2. It worked for the first input so the interviewer seemed satisfied.\n\nQ2. Link\n\nRound 2:\n\nQ1. Link\n\nQ2. Link\n\nSarath Chandra Reddy Motati\n\n1st Round (PROBLEM SOLVING ROUND) :\n\nAt the beginning interviewer introduced himself and asked “Tell me about yourself”, after \n\nThat we directly jumped into problem solving.\n\n   Question 1: A warm up question where I had to find the least missing non negative integer from the array.\n\n                     I quickly coded in O(nlogn) and improvised to O(n) using hashmap.\n\n   Question 2: I was given a nested list and I need to find the sum of each element multiplied with its depth.\n\n                     By that time I didn't know what a nested list was, so the interviewer explained to me by giving an example. Then I solved it by recursion.\n\nAfter solving these two questions there was around 5-10 min time left so he asked me to do the second question by using iterative method and while I was solving by using a queue, time ran out and we ended the session.\n\n2nd Round (PROBLEM SOLVING ROUND) :\n\nAt the beginning, interviewer asked how the previous round went and then we started solving coding questions.\n\nFirst question is based on trees and the second is based on dfs and backtracking.\n\nAfter coding both of them roughly 10-15 minutes left so he asked questions related to graphs . Asked some basic dfs,bfs questions and Dijkstra’s algorithm.  \n\n3rd Round (HR ROUND):\n\nSpent quite a time on CV. Was asked to explain about  the projects mentioned in CV and\n\nexplain everything . Spent around 15 mins to explain the algorithm used, how it worked , etc.\n\nFollowed up with questions like 'Why did you choose to do this ? What was the motivation? What difficulties did you face while making it? \n\nLater he asked to explain a coding question which you find challenging recently.\n\nAt the end I asked my doubts related to uipath and the interviewer answered and the session ended.\n\nTips for the UIPATH Interviews\n\n     Competitive programming is  most important.Both rounds are based on completely coding\n\n\n\nFocus on Trees and Graphs. Make sure that you can explain your projects for at least 10 minutes and with respect to me HR round is just for formality in uipath and main focus is on coding rounds. Try to solve both questions in time.\n\nUIPath interveiw questions and experiencs 2022\n\nOm Gunjal : selected\n\n1st Round (PROBLEM SOLVING ROUND) :\n\nAt the beginning the interviewer introduced himself and asked me to introduce myself.\n\nAfter that we jumped into problem solving. He gave me two questions one by one and told me to explain while solving. He gave me a link of a question from leetcode and told me to solve and run code on leetcode. Both que ...
#  Document(metadata={'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Internship Interview Experiences\\Zepto.docx'}, page_content="ZEPTO company interveiw questions and experiences\n\nAditya Gupta\n\nI'm excited to share my interview experience at Zepto Zetta Solutions Private Limited with you. It was a thorough process that checked both my technical skills and how well I fit with the company. \n\nFirst Round - Coding and OOPs:\n\nAt the beginning, I had a round where I had to solve coding problems and show my knowledge of Object-Oriented Programming (OOPs). \n\nThe problems were not too hard, and I managed to solve them. One was about using maps, and the other was about trees.\n\nThe interviewer helped me make my solutions better, and even though I couldn't finish the tree problem completely, I explained how I would do it. In the first question I was asked to give an array of size n(size of input array) - k(continuous element that to be taken) in which we have to give the different element present in a continuous subarray of size k. For the second question I was asked to make changes at every node of a binary tree resulting in the node value as the sum of all of its cousins. \n\nSecond Round - Coding and CP:\n\nIn the next round, I had to solve more coding problems, this time with a focus on competitive programming (CP). I talked about my thought process and solved a map problem quickly.\n\nFor a tree problem, I gave a step-by-step plan instead of writing the full code because of the time restrictions. I also ran my code with different inputs to show that it worked. \n\nFinal Round - HR and Project:\n\nThe last round was about getting to know me better and talking about my projects. I talked about myself and one of my projects. They were interested in the libraries and functions I used. We discussed whether I like working alone or in a group. They also asked about my day and if I had any questions about the company. \n\nOverall, the interview covered a lot of things – coding skills, problem-solving, explaining ideas, and seeing if I'd be a good fit for the team. I'm excited about the chance to work at Zepto Zetta Solutions and learn even more during my internship!")]

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
docs=text_splitter.split_documents(all_documents)

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
huggingface_embeddings=HuggingFaceBgeEmbeddings(
    model_name="BAAI/bge-base-en-v1.5",      
    model_kwargs={'device':'cpu'},
    encode_kwargs={'normalize_embeddings':True}

)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21840\748739886.py:2: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   huggingface_embeddings=HuggingFaceBgeEmbeddings(

# %%
from langchain_community.vectorstores import Chroma

db = Chroma.from_documents(all_documents, huggingface_embeddings)

# %%
query="what are the projects for quant roles"
result=db.similarity_search(query)
result
# Out:
# [Document(metadata={'total_pages': 15, 'page_label': '7', 'moddate': '2024-01-25T18:39:32+00:00', 'creator': 'Chromium', 'producer': '3-Heights™ PDF Optimization API 6.17.0.2 (http://www.pdf-tools.com)', 'creationdate': '2024-01-25T18:39:31+00:00', 'page': 6, 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\21-25 batch Intern Talk.pdf'}, page_content='•\n•\n•\n•\n•\n•\nSDE (Aryan Lath & vrooon, SWE Intern @ Google)\nQuant (Aditya Gupta, Quant Intern @ Quadeye)\nML/Data Science (Shantanu Chaudhari, DS Intern @ Infoedge)\nResearch [MITACS, EPFL,  …]\nDesign\nOff-campus\nRoles'),
#  Document(metadata={'page': 2, 'creator': 'PyPDF', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Internship Interview Experiences\\2023 DSAI Internship Experiences.pdf', 'producer': 'Skia/PDF m139 Google Docs Renderer', 'title': 'DSAI Internship Interview Experiences', 'page_label': '3', 'total_pages': 31, 'creationdate': ''}, page_content="Quadeye   Roles  offered:  Quant  and  Systems  \n Shortlisting:  No  coding  round,  they  do  resume  shortlisting  for  interviews.  CPI  criteria  to  apply  is  9  and  above.  \nEligible\n \nbranches\n \nwere\n \nCSE,\n \nMnC,\n \nECE,\n \nEEE\n \nin\n \nthe\n \ninitial\n \nmail,\n \nlater\n \nafter\n \nour\n \nBR(Thanish\n \n🙏🙏\n)\n \nsent\n \na\n \nlot\n \nof\n \nmails\n \nto\n \nCCD,\n \nQuadeye\n \nopened\n \nfor\n \nDSAI\n \nalso.\n For  shortlisting  they  are  looking  at  mainly  CPI,  dept  rank  and  JEE  adv  rank.  All  were  mostly  \n<1000\n \nJEE\n \nranks.\n \nThe\n \nshortlist\n \nwas\n \nreleased\n \nat\n \naround\n \n4pm,\n \nand\n \nonline\n \ninterviews\n \nwere\n \nthe\n \nnext\n \nday\n \n10am.\n  Note:  In  the  form  they  ask  which  roles  you  want  to  apply  for(quant  &  systems)  along  with  \npreference\n \norder.\n \nThose\n \nwho\n \napplied\n \nfor\n \nthe\n \nsystems\n \nrole\n \nwere\n \nshortlisted\n \nfor\n \nsystems\n \nrole\n \ninterviews\n \nirrespective\n \nof\n \npreference\n \norder,\n \nme\n \nand\n \nvarun\n \napplied\n \nonly\n \nfor\n \nquant\n \nrole,\n \nso\n \nwe\n \ngot\n \nquant\n \nrole\n \ninterviews.\n \nThis\n \ndoes\n \nnot\n \nmean\n \nthat\n \nyou\n \nshould\n \ndo\n \nthe\n \nsame\n \n(even\n \nif\n \nyou\n \nprefer\n \nquant\n \nover\n \nsystems)\n \n.\n \nI\n \ndidn't\n \napply\n \nfor\n \nsystems\n \nrole\n \nbecause\n \ni\n \nwasn't\n \nprepared\n \nfor\n \nit,\n \nyou\n \nshouldnt\n \nclose\n \nany\n \nopportunities\n \nin\n \nthe\n \nhope\n \nthat\n \nyou\n \nincrease\n \n“chances”\n \nof\n \nanother.\n \nEven\n \nafter\n \ngetting\n \nshortlisted\n \nfor\n \nsystems\n \nrole\n \ninterviews\n \nyou\n \ncan\n \nrequest\n \nfor\n \nquant\n \ninterviews\n \nduring\n \nthe\n \ninterview\n \nif\n \nyou\n \nare\n \nconfident\n \nin\n \nyour\n \npreparation\n \nand\n \npreferences.\n \n 1.  Aditya  Gupta  (Quant  Role)   Round  1  This  interviewer  was  a  IITB  CSE  graduate  who  joined  the  company  1  year  ago.   The  first  question  was,  in  a  2D  Random  Walk  where  you  can  go  in  any  of  the  4  directions  \nor\n \nstay\n \nin\n \nthe\n \nsame\n \nplace\n \nwith\n \nprob\n \n0.2\n \nfor\n \neach\n \nmove,\n \nhow\n \nwould\n \nyou\n \nfind\n \nthe\n \nexpected\n \ndistance\n \nof\n \nthe\n \nperson\n \nfrom\n \norigin\n \nafter\n \n20\n \nmoves(or\n \nn\n \nmoves).\n \nI\n \nthought\n \nthat\n \nhe\n \nwanted\n \na\n \nfinal\n \nanswer\n \nas\n \na\n \nclosed\n \nform\n \nsolution\n \nbut\n \nafter\n \naround\n \n20-25\n \nmins\n \nI\n \nunderstood\n \nthat\n \nhe\n \njust\n \nwanted\n \nto\n \nsee\n \nif\n \ni\n \ncould\n \nwrite\n \na\n \nrecurrence\n \nrelation\n \nof\n \nrandom\n \nwalk,\n \nhe\n \nwanted\n \nto\n \nknow\n \nhow\n \nI\n \ncould\n \nfind\n \nexpected\n \ndistance\n \nif\n \ni\n \ncould\n \nsimulate\n \nthe\n \nentire\n \nprocess.\n \nAfter\n \nI\n \ntold\n \nthe\n \nsolution,\n \nthe\n \ninterviewer\n \nsaid\n \nI\n \nwas\n \ncorrect\n \nbut\n \nwas\n \nunhappy\n \nI\n \ntook\n \nso\n \nlong\n \nand\n \neven\n \nasked\n \nme\n \nif\n \nI\n \nhad\n \neven\n \ntaken\n \nany\n \ncomputer\n \nscience\n \nand\n \nif\n \nI\n \nhad\n \neven\n \nstudied\n \nprobability.\n  The  2nd  question  was,  if  you  have  two  2D  random  walks  RW1,  where  you  have  5  \npossibilities(stay,\n \nleft,\n \nright,\n \nup,\n \ndown)\n \neach\n \nwith\n \nprob\n \n0.2\n \nfor\n \nevery\n \nmove,\n \nand\n \nRW2\n \nwhere\n \nyou\n \ncant\n \nstay\n \nat\n \nthe\n \nsame\n \npoint\n \nfor\n \na\n \nmove\n \nand\n \nyou\n \nhave\n \n4\n \npossibilities\n \neach\n \nwith\n \nprobability\n \n ...
#  Document(metadata={'page_label': '3', 'page': 2, 'title': 'CSEA Internship Prep Resources', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Internship Prep Resources\\CSEA Internship Prep Resources.pdf', 'creationdate': '', 'creator': 'PyPDF', 'producer': 'Skia/PDF m139 Google Docs Renderer', 'total_pages': 3}, page_content='Quant:  \nAll  the  sufficient  resources  for  quant  are  available  here.  Also  refer  to  Stat  110  course for  brushing  up  probability.  Try  to  complete  the  50  challenging  problems  in  probability  book  and  then  solve  the  puzzles  from  the  brainsteller  site.  To  get  an  idea  about  HFTs  you  can  watch  this  talk.     \nML  /  DataScience  \n1.  \nThis  is  a  good  playlist  to  brush  up  your  Probability:  Stat  110  course 2.  For  in  depth  reading  of  algorithms  you  can  take  help  of  StatQuest  channel.  3.  Interview  Problems (Machine  Learning  and  Deep  Learning  Sections  contain  most  relevant  questions)  \nSystem  Design  \n(only  for  Uber  in  Slot  1)  https://github.com/sharanyaa/grok_sdi_educative'),
#  Document(metadata={'page': 18, 'title': 'DSAI Internship Interview Experiences', 'creator': 'PyPDF', 'producer': 'Skia/PDF m139 Google Docs Renderer', 'page_label': '19', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Internship Interview Experiences\\2023 DSAI Internship Experiences.pdf', 'creationdate': '', 'total_pages': 31}, page_content="But  I  started  trying  a  XOR  approach.  I  was  close  to  finding  the  \nsolution,\n \nbut\n \nshe\n \ntold\n \nme\n \nto\n \ntry\n \na\n \ndifferent\n \napproach,\n \nas\n \nshe\n \nmight\n \nnot\n \nhave\n \nseen\n \nthe\n \nXOR\n \napproach\n \nbefore.\n After  the  interview,  I  figured  out  that  XOR  could  have  also  \nbeen\n \nused\n \nto\n \nreach\n \nthe\n \nsolution.\n  ●  Round  3  (HR)  A  very  chill  guy,  asked  me  about  the  real  life  use  case  of  one  of  my  \nprojects,\n \nabout\n \nmy\n \nPOR,\n \nwhy\n \nI\n \nwant\n \nto\n \nget\n \na\n \nquant\n \nrole,\n \nwhy\n \nJPMC\n \netc\n \netc.\n  ●  Verdict  -  Rejected  (2nd  interviewer  found  some  personality  issues)    ●  General  Tips:    ●  Analyst/Quant  Roles  expect  you  to  solve  almost  everything,  \nDSA,\n \npuzzles,\n \nprobability,\n \nlinear\n \nalgebra,\n \nML(if\n \nin\n \nresume),\n \nc++\n \netc.\n \nso\n \nbe\n \nprepared\n \nfor\n \nthat.\n ●  Some  people  I  talked  to,  had  a  whole  interview  on  Linear  \nAlgebra\n \nand\n \nCalculus\n \nonly\n \n(and\n \nthat\n \ntoo\n \nin\n \ndepth),\n \nsome\n \nwere\n \nasked\n \nC++\n \n/OOPS\n \nquestions,\n \nmath\n \nbehind\n \nthe\n \nML\n \nmodels\n \nthey\n \nused\n \nin\n \ntheir\n \nprojects,\n \nand\n \neven\n \ntough\n \nDSA\n \nquestions\n \nlike\n https://www.interviewbit.com/problems/egg-drop-problem/ ●  You  should  not  be  nervous,  but  also  don't  get  too  comfortable,  \nas\n \nthat\n \nmight\n \nmake\n \na\n \nbad\n \nimpression\n \non\n \nsome\n \ninterviewers.\n \n   2.  Shubhi  Agarwal  (Quant  Role)  ●  Round  1:   Mainly  puzzles  and  questions  on  probability  were  asked.  Especially  \nquestions\n \non\n \nCentral\n \nLimit\n \nTheorem.\n \nInterviewer\n \nwas\n \nfriendly\n \nand\n \nasked\n \nme\n \nif\n \nthere\n \nwas\n \na\n \nproject\n \nfrom\n \nJPMC\n \nI\n \nwas\n \ninterested\n \nin.\n \n Some  questions  asked  were;  ●  https://math.stackexchange.com/questions/3381462/hht-and-hth-in-tossing-a-coin,  I  was  able  to  solve  this.  ●  There  are  2  continuous  random  variables  in  [0,1],  they  are  \nindependent.\n \nFind\n \nE(max(X1,\n \nX2)).")]

# %%
ret=db.as_retriever()

# %%
from langchain_community.llms import Ollama
from langchain_core.prompts import ChatPromptTemplate

llm = Ollama(model="llama3")

prompt = ChatPromptTemplate.from_messages([
    ("system", "Answer me clearly from the context in depth, easy to understand. If you do this I will tip you $100."),
    ("human", "<context>\n{context}\n</context>\nQuestion: {input}")
])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21840\3179372262.py:4: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3")

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
doc_chain=create_stuff_documents_chain(llm,prompt)

# %%
from langchain.chains import create_retrieval_chain
rc=create_retrieval_chain(ret,doc_chain)

# %%
rc.invoke({"input":"give some projects that my seniors put in their cvs"})
# Out:
# {'input': 'give some projects that my seniors put in their cvs',
#  'context': [Document(metadata={'producer': 'Canva', 'creationdate': '2025-01-16T11:34:34+00:00', 'page_label': '25', 'moddate': '2025-01-16T11:34:31+00:00', 'page': 24, 'author': 'Sanjana Kolisetty', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'total_pages': 28, 'creator': 'Canva', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf'}, page_content='R e s u m e \nMention only those PORs and extracurricular activites for which you have\na certificate. \nPlease note that you will have to submit proof of every single point that\nyou write in you CV during CV submission.\nYour CV has to be only one page. If your CV is taking more than one page,\nthere has to be somethings which are not relevant or important.\nMake sure you know the courses that you are mentioning. For instance, if\nyou mention ‘Discrete Mathematics’ in your CV, be prepared to face\nquestions on it if your interviewer knows the subject.\nGet your Resume thoroughly reviewed by multiple seniors and peers.'),
#   Document(metadata={'title': 'DSAI Internship Interview Experiences', 'producer': 'Skia/PDF m139 Google Docs Renderer', 'page': 23, 'total_pages': 31, 'creationdate': '', 'page_label': '24', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Internship Interview Experiences\\2023 DSAI Internship Experiences.pdf', 'creator': 'PyPDF'}, page_content='●  General  Tips:    ●  People  who  have  written  some  fancy  vision  projects  in  their  \nresume\n \n(like\n \ninvolving\n \na\n \ngan\n \nor\n \na\n \ndiffuser),\n \nwere\n \nasked\n \nseveral\n \nquestions\n \non\n \nthe\n \nresearch\n \npaper\n \nof\n \nthese\n \nmodels.\n \nSo\n \nbe\n \nthorough\n \nwith\n \nthe\n \nmodels\n \nyou\n \ninclude\n \nin\n \nyour\n \nprojects\n \n(they\n \neven\n \nasked\n \nthe\n \nyear\n \nin\n \nwhich\n \nthe\n \nresearch\n \npaper\n \ncame).\n \n ●  People  with  no  background  in  Vision  were  asked  ML  in  depth  \n(they\n \nwere\n \nnot\n \nasking\n \nNLP\n \nrelated\n \nquestions).\n ●  Be  careful  in  the  HR  round,  as  my  interviewer  really  got  under  \nmy\n \nnerves.\n    2.  Aryan  Lath  (ML)  3.  Varun  Nagpal  (ML)  4.  Ankita  Anand  (ML)    \nGoogle  Roles  offered:  SWE  Coding  Test  Questions:  https://leetcode.com/discuss/interview-question/3767717/google-intern-swe-2023-OA https://leetcode.com/discuss/interview-question/3767661/google-OA https://www.thejoboverflow.com/p/p1294/ (you  can  try  to  find  them  on  leetcode,  I  think  there  were  total  5  unique  questions)   1.  Nityam  Pareek  (SWE):  Google’s  recruitment  process  consists  of  an  initial  shortlist  using  a  coding  \nround\n \nfollowed\n \nby\n \n2\n \nDSA\n \ninterview\n \nrounds.\n \nThey\n \ndo\n \nnot\n \nhave\n \nan\n \nHR\n \nround\n \nand\n \ndo\n \nnot\n \ndiscuss\n \nyour\n \nCV\n \nin\n \nany\n \ninterview.\n  a.  Coding  Round:  Google  is  usually  the  company  that  conducts  its  \ncoding\n \nround\n \nthe\n \nearliest.\n \nThis\n \nyear,\n \nit\n \nwas\n \nconducted\n \non\n \n15\n \nJuly.\n \nIt\n \nconsisted\n \nof\n \n2\n \nquestions\n \nto\n \nbe\n \nsolved\n \nin\n \n1\n \nhour,\n \nboth\n \nhaving\n \nmedium\n \nto\n \nhard\n \ndifficulty.\n \nHowever,\n \nthe\n \nquestions\n \ncan\n \nrepeat\n \nso\n \ndo\n \nask\n \nyour\n \nfriends\n \nfor\n \nquestions\n \nthey\n \nfound\n \nin\n \ntheir\n \ntest.\n \nThe\n \nquestions\n \nwere'),
#   Document(metadata={'producer': 'Canva', 'moddate': '2025-01-16T11:34:31+00:00', 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK', 'author': 'Sanjana Kolisetty', 'creationdate': '2025-01-16T11:34:34+00:00', 'page': 12, 'creator': 'Canva', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'page_label': '13', 'total_pages': 28}, page_content='I n t e r n \nS e a s o n \nP r o c e s s \nStep 1: CV Submission - happens in early July \n(We will conduct a Resume Talk before that to help\nyou with building a good resume).\nStep 2: CV Shortlisting - Students are shortlisted\nbased on CV to sit for Coding Rounds.\nStep 3: Coding Round - This is the toughest of all.\nGiven problems have to be solved in limited time.\nStep 4: Interviews - Students are further shortlisted\nfor interviews. There can be 3-5 rounds of interview.\nThe technical ones are usually followed by an HR\ninterview.'),
#   Document(metadata={'creationdate': '2025-01-16T11:34:34+00:00', 'creator': 'Canva', 'author': 'Sanjana Kolisetty', 'page': 25, 'page_label': '26', 'producer': 'Canva', 'total_pages': 28, 'keywords': 'DAGcWmjJ7no,BAE14CjFFr0', 'source': 'c:\\Users\\DELL\\OneDrive\\Desktop\\genai1\\data\\Intern Talks\\intren talk.pdf', 'moddate': '2025-01-16T11:34:31+00:00', 'title': 'Copy of INTERN TALK & SEMESTER-4 ACADEMIC TALK'}, page_content='P r o j e c t s \nMention atleast 3 good projects.\nThere must be a project in which you are absolutely confident in and can\nspeak about it for around 10-15 minutes.\nTech Stack for projects must be varied.\nRepositories must have an extremely good README and documentation.\nDeploy your projects if possible so that the interviewers can have a live\ninteractive demo of your project.\nProjects certified by a body are more plausible than self projects.\nBe thorough with your project as you will face lots of questions like what is\nthe motivation behind your project, what were the challenges in making\nthis, why did you use this techstack, what are the advantages of using this\ntechstack, what problem did your project solve etc.')],
#  'answer': "I'd be happy to help!\n\nBased on the context provided, here are some project ideas that your seniors might have mentioned in their CVs:\n\n1. **Personal Finance Manager**: A web application that allows users to track their expenses, income, and budget. Tech stack: React, Node.js, MongoDB.\n2. **Image Classification using Convolutional Neural Networks (CNN)**: A project that uses CNNs to classify images into different categories (e.g., animals, vehicles, buildings). Tech stack: Python, TensorFlow, Keras.\n3. **Natural Language Processing (NLP) Chatbot**: A chatbot that uses NLP techniques (e.g., sentiment analysis, entity recognition) to understand and respond to user input. Tech stack: Python, NLTK, spaCy, Rasa.\n4. **Game Development using Unity**: A game built using Unity, featuring 3D graphics, animations, and physics. Tech stack: C#, Unity, Blender.\n5. **Recommendation System for Music Streaming Platform**: A project that uses collaborative filtering and content-based filtering to recommend music tracks to users based on their listening history. Tech stack: Python, Pandas, NumPy, scikit-learn.\n6. **Real-time Object Detection using YOLO (You Only Look Once)**: A project that detects objects in real-time video feeds using the YOLO algorithm. Tech stack: Python, OpenCV, TensorFlow.\n7. **Sentiment Analysis of Social Media Posts**: A project that analyzes the sentiment of social media posts (e.g., Twitter, Facebook) and visualizes the results using a dashboard. Tech stack: Python, NLTK, spaCy, Tableau.\n\nThese projects are just examples, but they demonstrate a range of skills, including:\n\n* Web development\n* Machine learning and AI\n* NLP and text analysis\n* Game development\n* Data visualization\n\nRemember to be thorough with your project details and certifications, as mentioned in the context. Good luck!"}

# %%
from langchain_core.runnables import RunnableMap
rc1 = RunnableMap({
    "context": lambda x: ret.get_relevant_documents(x["input"]),
    "input": lambda x: x["input"]
}) | doc_chain

# %%
from pinecone import Pinecone
api="pcsk_4LLsH8_UxTh1J4odJSxT1ZbQeab7E6u8nRzuQcPK7YnNRxbmft3oADmjjSShCFvn3sqeAf"
pc = Pinecone(api_key=api)
index = pc.Index("intern")

# %%
from pinecone import Pinecone

# Initialize the Pinecone client
api = "pcsk_4LLsH8_UxTh1J4odJSxT1ZbQeab7E6u8nRzuQcPK7YnNRxbmft3oADmjjSShCFvn3sqeAf"
pc = Pinecone(api_key=api)

# Connect to your existing index
index = pc.Index("intern")

# Use Pinecone's inference API to get embeddings
response = pc.inference.embed(
    model="llama-text-embed-v2",
    inputs=[
        "Pinecone is amazing!",
        "LLaMA embeddings are fast and accurate."
    ],
    parameters={
        "input_type": "passage",
        "truncate": "END"
    }
)

# %%
from pinecone.grpc import PineconeGRPC as Pinecone

# Initialize client
pc = Pinecone(api_key=api)

# Example texts
texts = [
    "Pinecone is amazing!",
    "LLaMA embeddings are fast and accurate."
]

# Generate embeddings
response = pc.inference.embed(
    model="llama-text-embed-v2",
    inputs=texts,
    parameters={"input_type": "passage", "truncate": "END"}
)

# The returned object looks like:
# EmbeddingsList(model='llama-text-embed-v2', data=[ {...}, {...} ], usage={...})

# Loop over your original texts and response data
for text, item in zip(texts, response.data):
    print(f"Text: {text}")
    print("Embedding (first 5 dims):", item["values"][:5])
    print()
# Out:
# Text: Pinecone is amazing!
# Embedding (first 5 dims): [0.01496124267578125, 0.0052642822265625, 0.03076171875, 0.022308349609375, -0.01363372802734375]
#
# Text: LLaMA embeddings are fast and accurate.
# Embedding (first 5 dims): [-0.03668212890625, -0.0270538330078125, 0.0179443359375, 0.0188751220703125, 0.0635986328125]

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("data\Internship CVs\CE_CONSULTING_KPMG.pdf")
docs = loader.load()

print(f"✅ Pages loaded: {len(docs)}")
print("👉 Sample text:", docs[0].page_content[:500])
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\I'
# <>:3: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31616\1464838654.py:3: SyntaxWarning: invalid escape sequence '\I'
#   loader = PyPDFLoader("data\Internship CVs\CE_CONSULTING_KPMG.pdf")
# ✅ Pages loaded: 1
# 👉 Sample text: Utkarsh Utpal +91-6202999205
# Roll No.:210104113 u.utpal@iitg.ac.in
# B.Tech - Civil Engineering utkarshutpal04@gmail.com
# Indian Institute Of Technology, Guwahati linkedin
# Education
# Degree/Certificate Institute/Board CGPA/Percentage Year
# B.Tech. Major Indian Institute of Technology, Guwahati 7.41 (Current) 2021-Present
# Senior Secondary CBSE Board 90% 2021
# Secondary CBSE Board 95% 2019
# Experience
# • Finance Intern (CEO’s office) | Vedantu Ongoing
# Estimated criteria for short listing colleges for acqu

# %%
import fitz
doc = fitz.open("data\Internship CVs\CE_CONSULTING_KPMG.pdf")
text = ""
for page in doc:
    text += page.get_text("text")
print(text)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\I'
# <>:2: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31616\2662922457.py:2: SyntaxWarning: invalid escape sequence '\I'
#   doc = fitz.open("data\Internship CVs\CE_CONSULTING_KPMG.pdf")
# Utkarsh Utpal
# +91-6202999205
# Roll No.:210104113
# u.utpal@iitg.ac.in
# B.Tech - Civil Engineering
# utkarshutpal04@gmail.com
# Indian Institute Of Technology, Guwahati
# linkedin
# Education
# Degree/Certificate
# Institute/Board
# CGPA/Percentage
# Year
# B.Tech. Major
# Indian Institute of Technology, Guwahati
# 7.41 (Current)
# 2021-Present
# Senior Secondary
# CBSE Board
# 90%
# 2021
# Secondary
# CBSE Board
# 95%
# 2019
# Experience
# • Finance Intern (CEO’s office) | Vedantu
# Ongoing
# Estimated criteria for short listing colleges for acquisition, suggested intervention in the hybrid model
# – Modelled future 1 year P&L plan with EBITDA zero & predicted revenue of Rs 15cr for 10 hybrid centres in India
# – Empowered organic growth with 3 strategies by analysing 6 marketing lead sources with 20000+ leads
# – Suggested 15 colleges fit for acquisition or merger by analysing the online and offline education sector
# – Evaluated the financials of Urbane Academy to propose acquisition cost of Rs 40cr with a revenue multiple of 2
# • Government Intern | Delhi Metro Rail Corporation
# Jun 2023
# Assessed the proposed project plan to estimate cost and plan changes for metro rail construction in Patna
# – Investigated the project report to infer a change in the length of elevated section from 15.443 km to 13.529 km and
# underground section from 15.755 km to 18.584 km of the metro rail
# – Reviewed the city profile of Patna and demand estimates for metro to suggest an increment of 2 stations from 24
# – Estimated the cost of adjustments (Rs 114cr) suggested in the revised proposed project plan of Patna Metro
# Projects
# • Mutual Fund Management
# Sept 2022 - Feb 2023
# Finance and Economics Club, IITG
# Report
# – Conducted fundamental analysis of 50+ small & mid-cap companies to shortlist 10 companies from 9 sectors
# – Structured and co-authored the equity research report and executed DCF valuation for the 3 companies from energy,
# automotive and finance sector- Gail, Tube Investment of India & CDSL
# – Curated and pitched to gather a corpus of 70k for investment, which yielded a return of 10% with an alpha of 13%
# • Capstone Project- Air India’s Growth Stratergy
# Dec 2022
# Consulting and Analytic Club, IITG
# Report
# – Conducted global market research to conclude 7% annual growth of Indian aviation industry by 2030
# – Investigated Air India’s core problems, its business overview and its growth under Tata for SWOT analysis
# – Executed necessary guesstimates to predict the airlines passenger number of 18000 to devise its growth strategy
# • Union Budget Analysis FY 2023-24
# Jan 2023
# Finance and Economics Club, IITG
# Report
# – Analyzed the legislative changes, the budgeting strategy & the Saptarishi-7 Priorities highlighted in the budget
# – Analyzed the government’s direct and indirect taxation policies and expenditure by ministries and major schemes
# – Deduced the policy to reduce fiscal deficit and the policies impacting 10 sectors and highlighted the beneficiaries
# Positions of Responsibility
# • Capital Head,Finance and Economics Club, IIT Guwahati
# Apr 2023 - present
# – Leading a team of >90 sophomores to launch 3 finance based projects and accelerate finance culture in IIT Guwahati
# – Executed MnAnalyse: India’s largest Mergers Acquisitions Case Competition with 3000+ participants
# – Planning a pro-bono start up that provides financial consultancy to emerging startups and campus businesses
# – Organised 6 competitions& workshops with 5k+ participants & collaborations with entities like The Trading Street
# – Organised a build-from-scratch sealed Bid auction based on Game Theory with 500+ participants
# Achievements
# • Winner, business Cup, Kriti, an Equity Research Competition ( 100+ participants from IITG)
# 2023
# • Student-Run Mutual Fund, Built a portfolio of 10 stocks and 3+ trading strategies to maximize returns
# 2023
# • Finlatics Market Experience Programme, generated 7% return over 1 month with an alpha of 6%
# Ongoing
# • Project Intern, Road Development Corporation, Govt. of Bihar, explored construction management
# 2022
# • Academic Excellence’s Award, received for 5 consecutive years in school
# 2015-2019
# • Courses Taken
# – BCG Strategy consulting virtual experience programme, Behavioral Finance, Global Financial Markets, Portfolio
# Selection and Risk Management, Investment Strategy and Portfolio Analysis, Corporate Finance
# Extracurricular
# • Community Service Volunteer, NSS IITG,Increased engagement in Aashman foundation by campaigning
# 2023
# • Spirit, Sports fest,Facilitated 50+ participants from 4+ institutes for 2000+ audience
# 2023
# • Intra School Sports Competition,2nd runner-up in badminton & 3rd runner-up in table tennis
# 2017
# • Social Science Exhibition,Winner, Crafted a miniature model of an ideal smart city using recycled materials
# 2018

# %%
len(text)
print(text)
# Out:
# Utkarsh Utpal
# +91-6202999205
# Roll No.:210104113
# u.utpal@iitg.ac.in
# B.Tech - Civil Engineering
# utkarshutpal04@gmail.com
# Indian Institute Of Technology, Guwahati
# linkedin
# Education
# Degree/Certificate
# Institute/Board
# CGPA/Percentage
# Year
# B.Tech. Major
# Indian Institute of Technology, Guwahati
# 7.41 (Current)
# 2021-Present
# Senior Secondary
# CBSE Board
# 90%
# 2021
# Secondary
# CBSE Board
# 95%
# 2019
# Experience
# • Finance Intern (CEO’s office) | Vedantu
# Ongoing
# Estimated criteria for short listing colleges for acquisition, suggested intervention in the hybrid model
# – Modelled future 1 year P&L plan with EBITDA zero & predicted revenue of Rs 15cr for 10 hybrid centres in India
# – Empowered organic growth with 3 strategies by analysing 6 marketing lead sources with 20000+ leads
# – Suggested 15 colleges fit for acquisition or merger by analysing the online and offline education sector
# – Evaluated the financials of Urbane Academy to propose acquisition cost of Rs 40cr with a revenue multiple of 2
# • Government Intern | Delhi Metro Rail Corporation
# Jun 2023
# Assessed the proposed project plan to estimate cost and plan changes for metro rail construction in Patna
# – Investigated the project report to infer a change in the length of elevated section from 15.443 km to 13.529 km and
# underground section from 15.755 km to 18.584 km of the metro rail
# – Reviewed the city profile of Patna and demand estimates for metro to suggest an increment of 2 stations from 24
# – Estimated the cost of adjustments (Rs 114cr) suggested in the revised proposed project plan of Patna Metro
# Projects
# • Mutual Fund Management
# Sept 2022 - Feb 2023
# Finance and Economics Club, IITG
# Report
# – Conducted fundamental analysis of 50+ small & mid-cap companies to shortlist 10 companies from 9 sectors
# – Structured and co-authored the equity research report and executed DCF valuation for the 3 companies from energy,
# automotive and finance sector- Gail, Tube Investment of India & CDSL
# – Curated and pitched to gather a corpus of 70k for investment, which yielded a return of 10% with an alpha of 13%
# • Capstone Project- Air India’s Growth Stratergy
# Dec 2022
# Consulting and Analytic Club, IITG
# Report
# – Conducted global market research to conclude 7% annual growth of Indian aviation industry by 2030
# – Investigated Air India’s core problems, its business overview and its growth under Tata for SWOT analysis
# – Executed necessary guesstimates to predict the airlines passenger number of 18000 to devise its growth strategy
# • Union Budget Analysis FY 2023-24
# Jan 2023
# Finance and Economics Club, IITG
# Report
# – Analyzed the legislative changes, the budgeting strategy & the Saptarishi-7 Priorities highlighted in the budget
# – Analyzed the government’s direct and indirect taxation policies and expenditure by ministries and major schemes
# – Deduced the policy to reduce fiscal deficit and the policies impacting 10 sectors and highlighted the beneficiaries
# Positions of Responsibility
# • Capital Head,Finance and Economics Club, IIT Guwahati
# Apr 2023 - present
# – Leading a team of >90 sophomores to launch 3 finance based projects and accelerate finance culture in IIT Guwahati
# – Executed MnAnalyse: India’s largest Mergers Acquisitions Case Competition with 3000+ participants
# – Planning a pro-bono start up that provides financial consultancy to emerging startups and campus businesses
# – Organised 6 competitions& workshops with 5k+ participants & collaborations with entities like The Trading Street
# – Organised a build-from-scratch sealed Bid auction based on Game Theory with 500+ participants
# Achievements
# • Winner, business Cup, Kriti, an Equity Research Competition ( 100+ participants from IITG)
# 2023
# • Student-Run Mutual Fund, Built a portfolio of 10 stocks and 3+ trading strategies to maximize returns
# 2023
# • Finlatics Market Experience Programme, generated 7% return over 1 month with an alpha of 6%
# Ongoing
# • Project Intern, Road Development Corporation, Govt. of Bihar, explored construction management
# 2022
# • Academic Excellence’s Award, received for 5 consecutive years in school
# 2015-2019
# • Courses Taken
# – BCG Strategy consulting virtual experience programme, Behavioral Finance, Global Financial Markets, Portfolio
# Selection and Risk Management, Investment Strategy and Portfolio Analysis, Corporate Finance
# Extracurricular
# • Community Service Volunteer, NSS IITG,Increased engagement in Aashman foundation by campaigning
# 2023
# • Spirit, Sports fest,Facilitated 50+ participants from 4+ institutes for 2000+ audience
# 2023
# • Intra School Sports Competition,2nd runner-up in badminton & 3rd runner-up in table tennis
# 2017
# • Social Science Exhibition,Winner, Crafted a miniature model of an ideal smart city using recycled materials
# 2018
